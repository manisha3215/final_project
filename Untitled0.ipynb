# %% [markdown]
# <a href="https://colab.research.google.com/github/manisha3215/final_project/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -qq install -y libsm6 libxext6 && pip install -q -U opencv-python
import cv2

# %%
from google.colab import files
file=files.upload()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
face_cascade=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
imj=cv2.imread("hero.jpg")
gray_img=cv2.cvtColor(imj,cv2.COLOR_BGR2GRAY)
faces=face_cascade.detectMultiScale(gray_img,scaleFactor=1.5,minNeighbors=5)
print(faces)
# Out:
# [[ 53  67 182 182]]

# %%
for (x,y,w,h) in faces:
  cv2.rectangle(imj,(x,y),(x+w,y+h),(255,0,0),3)
  
cv2_imshow(imj)
# Out:
# <PIL.Image.Image image mode=RGB size=435x653 at 0x7F85E1D91588>
